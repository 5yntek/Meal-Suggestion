# %%
# !python train.py --img 640 --batch 16 --epochs 5 --data food.yaml --weights yolov5s.pt
# Out:
# github:  WARNING: code is out of date by 45 commits. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# YOLOv5 v4.0-93-g95aefea torch 1.7.1 CUDA:0 (GeForce GTX 1060 6GB, 6144.0MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='', data='.\\data\\food.yaml', device='', epochs=5, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], linear_lr=False, local_rank=-1, log_artifacts=False, log_imgs=16, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs\\train\\exp', single_cls=False, sync_bn=False, total_batch_size=16, weights='yolov5s.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# ...

# %%
from utils.plots import plot_results
plot_results(save_dir='runs/train/exp')  # plot results.txt as results.png

# %%
# test, choose correct weights
# !python test.py --weights C:\projects\mealsuggestion\yolov5\runs\train\exp\weights\best.pt --data food.yaml --img 640 --iou 0.65
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='.\\data\\food.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.65, name='exp', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=False, single_cls=False, task='val', verbose=False, weights=['C:\\projects\\mealsuggestion\\yolov5\\runs\\train\\exp\\weights\\best.pt'])
# Fusing layers...
#                  all         708    2.84e+03        0.44       0.407       0.374       0.221
#               banana         708         379       0.395       0.315       0.277       0.127
#                apple         708         239       0.313       0.259       0.212       0.127
#             sandwich         708         177       0.491       0.419       0.422       0.251
#               orange         708         287       0.407       0.425       0.362       0.259
#             broccoli         708         316       0.504       0.285       0.338       0.151
# ...

# %%
# !python test.py --weights C:\projects\mealsuggestion\yolov5\weights\yolov5s.pt --data food_coco.yaml --img 640 --iou 0.65
# Out:
# train: Scanning '..\food\labels\train' for images and labels... 7154 found, 0 missing, 0 empty, 0 corrupted:  44%|####4     | 7154/16255 [01:12<01:42, 88.76it/s]
# train: Scanning '..\food\labels\train' for images and labels... 7163 found, 0 missing, 0 empty, 0 corrupted:  44%|####4     | 7163/16255 [01:12<01:45, 86.56it/s]
# train: Scanning '..\food\labels\train' for images and labels... 7172 found, 0 missing, 0 empty, 0 corrupted:  44%|####4     | 7172/16255 [01:12<01:44, 86.80it/s]
# train: Scanning '..\food\labels\train' for images and labels... 7181 found, 0 missing, 0 empty, 0 corrupted:  44%|####4     | 7181/16255 [01:12<01:43, 87.74it/s]
# train: Scanning '..\food\labels\train' for images and labels... 7191 found, 0 missing, 0 empty, 0 corrupted:  44%|####4     | 7191/16255 [01:12<01:41, 88.90it/s]
# train: Scanning '..\food\labels\train' for images and labels... 7201 found, 0 missing, 0 empty, 0 corrupted:  44%|####4     | 7201/16255 [01:13<01:41, 89.02it/s]
# ...

# %%
# test trained model / simulated data
# !python test.py --weights C:\projects\mealsuggestion\yolov5\runs\train\exp\weights\best.pt --data simulation.yaml --img 640 --iou 0.65
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='.\\data\\simulation.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.65, name='exp', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=False, single_cls=False, task='val', verbose=False, weights=['C:\\projects\\mealsuggestion\\yolov5\\runs\\train\\exp\\weights\\best.pt'])
# Fusing layers...
#                  all         500    1.37e+03       0.478       0.479       0.476       0.303
#               banana         500         147       0.846       0.878       0.895       0.604
#                apple         500         193       0.623       0.675       0.711       0.524
#             sandwich         500         144           0           0     0.00574    0.000951
#               orange         500         204       0.345       0.713       0.401         0.3
#             broccoli         500         146       0.235       0.247       0.147      0.0251
# ...

# %%
# test pre-trained model / simulated data
# !python test.py --weights C:\projects\mealsuggestion\yolov5\weights\yolov5s.pt --data simulation_coco.yaml --img 640 --iou 0.65
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='.\\data\\simulation_coco.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.65, name='exp', project='runs/test', save_conf=False, save_hybrid=False, save_json=True, save_txt=False, single_cls=False, task='val', verbose=False, weights=['C:\\projects\\mealsuggestion\\yolov5\\weights\\yolov5s.pt'])
# Fusing layers...
#                  all         500    1.37e+03       0.562       0.521       0.552       0.384
# Speed: 6.7/3.5/10.3 ms inference/NMS/total per 640x640 image at batch-size 32
#
# Evaluating pycocotools mAP... saving runs\test\exp10\yolov5s_predictions.json...
# loading annotations into memory...
# Done (t=1.09s)
# creating index...
# index created!
# Loading and preparing results...
# pycocotools unable to run: Results do not correspond to current coco set
# Results saved to runs\test\exp10
# YOLOv5 v4.0-93-g95aefea torch 1.7.1 CUDA:0 (GeForce GTX 1060 6GB, 6144.0MB)
#
# ...
